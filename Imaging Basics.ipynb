# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread('Dwayne-Johnson.jpg')
print('Shape of image: {}'.format(image.shape))
# Out:
# Shape of image:(739, 670, 3)

# %%
plt.imshow(image)

# %% [markdown]
# # RGB image basics
# Since most color images (95%) of them are arranged in Red, Green, Blue color channel.

# %%
red_ch = image[:, :, 0]
green_ch = image[:, :, 1]
blue_ch = image[:, :, 2]

# %%
plt.imshow(red_ch)

# %%
plt.imshow(green_ch)

# %%
plt.imshow(blue_ch)
